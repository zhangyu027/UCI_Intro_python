# %%
2 + 2

# %%
50 - 4*6

# %%
5 **2

# %%
string = "hello world"
print(string)

# %%
name = 'Yu' + ' ' + 'Zhang'
print(name)

# %%
name = 'Yu' + " " + "Zhang"

# %%
name

# %%
list = [1, 2, 3, 4]
print(list)

# %%
list = {1,2,3}
list

# %%
tuple = (1,2,3,4)
print(tuple)
