# %% [markdown]
# # BrightMart Retail Analytics Portfolio Notebook
#
# Add your introduction here.

# %% [markdown]
# ## 1. Business Problem
#
# Describe the business question.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Data Loading

# %%
# df = pd.read_csv('data/BrightMart_Retail_Dataset.csv')
# df.head()

# %% [markdown]
# ## 3. Data Cleaning
#
# Document your cleaning steps.

# %% [markdown]
# ## 4. Exploratory Analysis
#
# Add tables and charts.

# %% [markdown]
# ## 5. Recommendations
#
# Add evidence-based recommendations.

# %% [markdown]
# ## 6. Reflection
#
# What did you learn?
