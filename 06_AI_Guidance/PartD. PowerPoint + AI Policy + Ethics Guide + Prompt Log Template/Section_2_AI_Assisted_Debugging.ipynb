# %% [markdown]
# # Section 2: AI-Assisted Debugging
# Learn to use ChatGPT to understand and fix Python/pandas errors.

# %% [markdown]
# ## Learning Objectives
# - Read traceback messages
# - Write effective debugging prompts
# - Verify AI fixes

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis'
DATA_DIR = f'{BASE_DIR}/05_Datasets'
ASSIGNMENTS_DIR = f'{BASE_DIR}/04_Assignments'
OUTPUTS_DIR = f'{BASE_DIR}/04_Assignments/Outputs'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis/06_AI_Guidance/PartD. PowerPoint + AI Policy + Ethics Guide + Prompt Log Template/BrightMart_Retail_Dataset.csv')
df.head()
# Out:
#    OrderID   OrderDate Region         Category CustomerSegment    Sales  \
# 0   100000  2025-06-15   West       Technology        Consumer  4740.37
# 1   100001  2025-08-11  South  Office Supplies        Consumer  2102.50
# 2   100002  2025-10-27   East  Office Supplies        Consumer  1995.47
# 3   100003  2025-10-25   West        Furniture       Corporate  2864.60
# 4   100004  2025-08-21   East        Furniture       Corporate  1820.68
#
#    Discount  Profit  Quantity
# 0      0.15  710.59         2
# 1      0.05 -121.23        10
# 2      0.05 -152.93         2
# 3      0.05  181.80        10
# 4      0.05  445.91        10

# %% [markdown]
# ## Exercise 1: KeyError

# %%
# Intentional error
# df.groupby('region')['Sales'].sum()

# %% [markdown]
# **Prompt:** Explain why this KeyError occurs and show corrected code.

# %%
df.groupby('Region')['Sales'].sum().head()
# Out:
# Region
# Central    2406377.69
# East       2491995.07
# South      2376625.83
# West       2579725.29
# west        156208.11
# Name: Sales, dtype: float64

# %% [markdown]
# ## Exercise 2: ValueError

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'],errors='coerce')
print(df['OrderDate'].isna().sum())
# Out:
# 32

# %% [markdown]
# Prompt: Why do invalid dates become NaT?

# %% [markdown]
# ## Exercise 3: TypeError

# %%
# Example:
# '100'+5

# %% [markdown]
# Ask AI to explain the error and fix it.

# %% [markdown]
# ## Exercise 4: AttributeError

# %%
# Example:
# df['Sales'].upper()

# %% [markdown]
# Prompt: Explain why Series has no attribute upper.

# %% [markdown]
# ## Debugging Checklist
# 1. Read traceback
# 2. Inspect columns
# 3. Check data types
# 4. Test fix
# 5. Verify output

# %% [markdown]
# ## Reflection
# What debugging strategy was most helpful? When should you not trust AI?
