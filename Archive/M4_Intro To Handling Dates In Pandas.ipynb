# %% [markdown]
# # Intro To Handling Dates In Pandas
# Properly handling dates in Pandas can be very useful.  For example, let's say you read in a csv of temperature data with dates and you'd like to find the monthly mean temperature.  If the date column is already recognized, by pandas, as a date type, then extracting the month from the column will be very easy.  If the date column is, instead, read in as a string type, then it will be more difficult to extract the month.
#
# ## Notebook Outline
# * [Using the parse dates .read_csv() to automatically read in dateformats](#parsedates)
# * [Using .to_datetime() to convert a column to a pandas datetime format](#todatetime)
# * [Using .dt on datetime columns](#dtattribute)
# * [Introduction the .min(), .max() and .sum() methods](#minmaxsum)

# %% [markdown]
# # Google Colab Path Note
#
# If you run this notebook in Google Colab, mount Google Drive first:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis'
# DATA_DIR = f'{BASE_DIR}/05_Datasets'
# ASSIGNMENTS_DIR = f'{BASE_DIR}/04_Assignments'
# OUTPUTS_DIR = f'{BASE_DIR}/04_Assignments/Outputs'
# ```
#
# If you run locally in Jupyter/Anaconda, do not use `/content/drive`; use relative paths such as `../05_Datasets/...`.
# The Mac path `/Users/yuzhang/.../My Drive/...` is only for local file browsing and is not a Colab path.

# %%
import pandas as pd

# %% [markdown]
# <a name=parsedates></a>
# # Using the parse_dates argument in .read_csv() to automatically read in date formats
# When reading in a file, we can specify which columns, or which combinations of columns, we would like read in as a datetime type. For this example, I am going to introduce a new data file 'LaborSheetData.csv'. This file contains real data from a very popular fast food store. Every hour, the shift manager must enter some key data in this file, like drive through times and sales for the past hour. This will be a good dataset for us to explore in some of our lectures.
#
# First we will load the data. Remember that you will need to change the path to point to where you place the file on your computer, after you download it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filepath = ('/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis/05_Datasets/M5_LaborSheetData.csv')
laborSheetData = pd.read_csv(filepath)

# %% [markdown]
# #### Use the .head() method to get a look at the data, and the .info method to see the data types

# %%
laborSheetData.head(2)
# Out:
#             Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0  Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1  Training Store    2022-01-03  01:00  Breakfast            87      733.5
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
#
#    Promotion_Flag  Customer_Satisfaction            Timestamp
# 0            True                   4.00  2022-01-03 00:00:00
# 1           False                   4.15  2022-01-03 01:00:00

# %%
laborSheetData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Store                   42 non-null     object
#  1   Business_Date           42 non-null     object
#  2   Hour                    42 non-null     object
#  3   Day_Part                42 non-null     object
#  4   Transactions            42 non-null     int64
#  5   Net_Sales               42 non-null     float64
#  6   Labor_Hours             42 non-null     float64
#  7   Drive_Thru_Avg_Seconds  42 non-null     int64
#  8   Crew_Count              42 non-null     int64
#  9   Manager                 42 non-null     object
#  10  Weather                 42 non-null     object
#  11  Promotion_Flag          42 non-null     bool
#  12  Customer_Satisfaction   42 non-null     float64
#  13  Timestamp               42 non-null     object
# dtypes: bool(1), float64(3), int64(3), object(7)
# memory usage: 4.4+ KB

# %% [markdown]
# #### Note that data types of the Date and TimeStamp columns
# The data types are object, which means they were read in as strings. Let's double check that by grabbing a value from the data column using the .loc() method and finding its type with the type function.

# %%
type(laborSheetData.loc[0, 'Business_Date'])
# Out:
# str

# %%
laborSheetData['Business_Date'] = pd.to_datetime(laborSheetData['Business_Date'])
laborSheetData.groupby(by = 'Business_Date').mean(numeric_only=True)
# Out:
#                Transactions    Net_Sales  Labor_Hours  Drive_Thru_Avg_Seconds  \
# Business_Date
# 2022-01-03          105.375   984.000000       13.125                   151.5
# 2022-01-04          108.000  1044.305556       13.125                   148.5
#
#                Crew_Count  Promotion_Flag  Customer_Satisfaction
# Business_Date
# 2022-01-03       5.916667        0.166667               4.287500
# 2022-01-04       5.944444        0.111111               4.291667

# %% [markdown]
# #### Now, we will use the parse_dates argument to automatically read the date columns in as date types.
# All we need to do is pass a list of the columns we would like pandas to try and automatically decipher as date or time objects to the parse_dates argument.  If you look above at the output from .info, you will see that the date or datetime columns are columns 2 and 13 (remember that counting starts at 0).
#
# Note that this will cause the read_csv() method to take a little bit longer to complete.

# %%
laborSheetData = pd.read_csv(filepath, parse_dates=[2, 13])
# Out:
# /tmp/ipykernel_877/90362290.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   laborSheetData = pd.read_csv(filepath, parse_dates=[2, 13])

# %%
laborSheetData.head(2)
# Out:
#             Store Business_Date                Hour   Day_Part  Transactions  \
# 0  Training Store    2022-01-03 2026-06-19 00:00:00  Breakfast            80
# 1  Training Store    2022-01-03 2026-06-19 01:00:00  Breakfast            87
#
#    Net_Sales  Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager  \
# 0      650.0        10.00                     120           4  Sample Manager
# 1      733.5        11.25                     129           5  Sample Manager
#
#   Weather  Promotion_Flag  Customer_Satisfaction           Timestamp
# 0    Rain            True                   4.00 2022-01-03 00:00:00
# 1   Clear           False                   4.15 2022-01-03 01:00:00

# %% [markdown]
# #### Now use .info() to check our datatypes.
# Note that the 'Date' and 'TimeStamp' columns are now datetime types!

# %%
laborSheetData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Store                   42 non-null     object
#  1   Business_Date           42 non-null     object
#  2   Hour                    42 non-null     datetime64[ns]
#  3   Day_Part                42 non-null     object
#  4   Transactions            42 non-null     int64
#  5   Net_Sales               42 non-null     float64
#  6   Labor_Hours             42 non-null     float64
#  7   Drive_Thru_Avg_Seconds  42 non-null     int64
#  8   Crew_Count              42 non-null     int64
#  9   Manager                 42 non-null     object
#  10  Weather                 42 non-null     object
#  11  Promotion_Flag          42 non-null     bool
#  12  Customer_Satisfaction   42 non-null     float64
#  13  Timestamp               42 non-null     datetime64[ns]
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(3), object(5)
# memory usage: 4.4+ KB

# %% [markdown]
# #### Now let's use the parse_dates argument to _combine_ two (or more) columns into one datetime.
# For this, I need to give you some information about this data. The 'TimeStamp' column let's us know when the data was entered, but the 'Date' + 'Hour' column let us know what hour the data is for.  So it would be great if we could combine the Date and Hour columns into one datetime column!
#
# We can do this using the parse_dates argument. All we need to do is include a list, of the columns we want to combine, as one of the items in the list that we we pass to the parse_dates argument.
#
# Note that pandas will create a _new_ column called 'Date_Hour' that combines the 'Date' and 'Hour' columns two columns.

# %%
laborSheetData = pd.read_csv(filepath, parse_dates=[[2, 3], 13])
# Out:
# /tmp/ipykernel_877/315118610.py:1: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   laborSheetData = pd.read_csv(filepath, parse_dates=[[2, 3], 13])
# /tmp/ipykernel_877/315118610.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   laborSheetData = pd.read_csv(filepath, parse_dates=[[2, 3], 13])

# %%
laborSheetData.head(2)
# Out:
#      Hour_Day_Part           Store Business_Date  Transactions  Net_Sales  \
# 0  00:00 Breakfast  Training Store    2022-01-03            80      650.0
# 1  01:00 Breakfast  Training Store    2022-01-03            87      733.5
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
#
#    Promotion_Flag  Customer_Satisfaction           Timestamp
# 0            True                   4.00 2022-01-03 00:00:00
# 1           False                   4.15 2022-01-03 01:00:00

# %%
laborSheetData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hour_Day_Part           42 non-null     object
#  1   Store                   42 non-null     object
#  2   Business_Date           42 non-null     object
#  3   Transactions            42 non-null     int64
#  4   Net_Sales               42 non-null     float64
#  5   Labor_Hours             42 non-null     float64
#  6   Drive_Thru_Avg_Seconds  42 non-null     int64
#  7   Crew_Count              42 non-null     int64
#  8   Manager                 42 non-null     object
#  9   Weather                 42 non-null     object
#  10  Promotion_Flag          42 non-null     bool
#  11  Customer_Satisfaction   42 non-null     float64
#  12  Timestamp               42 non-null     datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(3), object(5)
# memory usage: 4.1+ KB

# %% [markdown]
# ## Let's see another example using our weather data.
# Firs we will load the weather data and use .head() to look at the data.  Note that the first four columns are Year, Month, Day, and Hour.

# %%
filepath = ('/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis/05_Datasets/M1_724080-13739-2001')
headers = ['Year', 'Month', 'Day', 'Hour', 'Air Temp', 'Dew Point Temp', 'Sea Level Pressure',
           'Wind Direction', 'Wind Speed Rate',
           'Sky Condition Total Coverage Code',
           'Liquid Precipitation Depth Dimension - 1Hr Duration',
           'Liquid Precipitation Depth Dimension - Six Hour Duration']
weatherData = pd.read_csv(filepath, delim_whitespace=True,
                          names=headers)
# Out:
# /tmp/ipykernel_877/3704144353.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   weatherData = pd.read_csv(filepath, delim_whitespace=True,

# %%
weatherData.head(1)
# Out:
#    Year  Month  Day  Hour  Air Temp  Dew Point Temp  Sea Level Pressure  \
# 0  2022      1    1     0        80              80               10120
#
#    Wind Direction  Wind Speed Rate  Sky Condition Total Coverage Code  \
# 0             180               35                                  1
#
#    Liquid Precipitation Depth Dimension - 1Hr Duration  \
# 0                                                  0
#
#    Liquid Precipitation Depth Dimension - Six Hour Duration
# 0                                                  0

# %% [markdown]
# #### Now, use parse_dates to reload the data and combine the first four columns into one datetime column

# %%
weatherData = pd.read_csv(filepath, delim_whitespace=True,
                          names=headers, parse_dates=[[0, 1, 2, 3]])
# Out:
# /tmp/ipykernel_877/1303751619.py:1: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   weatherData = pd.read_csv(filepath, delim_whitespace=True,
# /tmp/ipykernel_877/1303751619.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   weatherData = pd.read_csv(filepath, delim_whitespace=True,
# /tmp/ipykernel_877/1303751619.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weatherData = pd.read_csv(filepath, delim_whitespace=True,

# %%
weatherData.head(2)
# Out:
#   Year_Month_Day_Hour  Air Temp  Dew Point Temp  Sea Level Pressure  \
# 0          2022 1 1 0        80              80               10120
# 1          2022 1 1 1        85              80               10120
#
#    Wind Direction  Wind Speed Rate  Sky Condition Total Coverage Code  \
# 0             180               35                                  1
# 1             180               35                                  1
#
#    Liquid Precipitation Depth Dimension - 1Hr Duration  \
# 0                                                  0
# 1                                                  0
#
#    Liquid Precipitation Depth Dimension - Six Hour Duration
# 0                                                  0
# 1                                                  0

# %%
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 9 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Year_Month_Day_Hour                                       72 non-null     object
#  1   Air Temp                                                  72 non-null     int64
#  2   Dew Point Temp                                            72 non-null     int64
#  3   Sea Level Pressure                                        72 non-null     int64
#  4   Wind Direction                                            72 non-null     int64
#  5   Wind Speed Rate                                           72 non-null     int64
#  6   Sky Condition Total Coverage Code                         72 non-null     int64
#  7   Liquid Precipitation Depth Dimension - 1Hr Duration       72 non-null     int64
#  8   Liquid Precipitation Depth Dimension - Six Hour Duration  72 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# <a name=todatetime></a>
# # Using pandas.to_datetime() to convert a column of strings to a columns of DateTime objects
# Sometimes, we need to convert a column after we read in the data. Maybe we have created the column during data processing. We can do this with the to_datetime() function in the pandas package.
#
# I am going to read in the labor sheet data again, without using parse_dates.

# %%
filepath = ('/content/drive/MyDrive/Colab Notebooks/UCI/UCI_427.62_Python_for_Data_Analysis/05_Datasets/M5_LaborSheetData.csv')
laborSheetData = pd.read_csv(filepath)
laborSheetData.head()
# Out:
#             Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0  Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1  Training Store    2022-01-03  01:00  Breakfast            87      733.5
# 2  Training Store    2022-01-03  02:00  Breakfast            94      817.0
# 3  Training Store    2022-01-03  03:00  Breakfast           101      900.5
# 4  Training Store    2022-01-03  04:00  Breakfast           108      984.0
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
# 2        12.50                     138           6  Sample Manager   Clear
# 3        13.75                     147           7  Sample Manager   Clear
# 4        15.00                     156           8  Sample Manager    Rain
#
#    Promotion_Flag  Customer_Satisfaction            Timestamp
# 0            True                   4.00  2022-01-03 00:00:00
# 1           False                   4.15  2022-01-03 01:00:00
# 2           False                   4.30  2022-01-03 02:00:00
# 3           False                   4.45  2022-01-03 03:00:00
# 4           False                   4.60  2022-01-03 04:00:00

# %%
laborSheetData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Store                   42 non-null     object
#  1   Business_Date           42 non-null     object
#  2   Hour                    42 non-null     object
#  3   Day_Part                42 non-null     object
#  4   Transactions            42 non-null     int64
#  5   Net_Sales               42 non-null     float64
#  6   Labor_Hours             42 non-null     float64
#  7   Drive_Thru_Avg_Seconds  42 non-null     int64
#  8   Crew_Count              42 non-null     int64
#  9   Manager                 42 non-null     object
#  10  Weather                 42 non-null     object
#  11  Promotion_Flag          42 non-null     bool
#  12  Customer_Satisfaction   42 non-null     float64
#  13  Timestamp               42 non-null     object
# dtypes: bool(1), float64(3), int64(3), object(7)
# memory usage: 4.4+ KB

# %% [markdown]
# #### Use to_datetime to convert the 'TimeStamp' column to a column of datetime objects.
# Note that to_datetime can not combine multiple columns (except under a few specific circumstances) so we can not use it to combine the 'Date' and 'Hour' columns.

# %%
laborSheetData.loc[:, 'Timestamp'] = pd.to_datetime(laborSheetData['Timestamp'])

# %%
laborSheetData.groupby(by='Timestamp').head()
# Out:
#              Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0   Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1   Training Store    2022-01-03  01:00  Breakfast            87      733.5
# 2   Training Store    2022-01-03  02:00  Breakfast            94      817.0
# 3   Training Store    2022-01-03  03:00  Breakfast           101      900.5
# 4   Training Store    2022-01-03  04:00  Breakfast           108      984.0
# 5   Training Store    2022-01-03  05:00  Breakfast           115     1067.5
# 6   Training Store    2022-01-03  06:00  Breakfast           122     1151.0
# 7   Training Store    2022-01-03  07:00  Breakfast           129     1234.5
# 8   Training Store    2022-01-03  08:00  Breakfast           136     1318.0
# 9   Training Store    2022-01-03  09:00  Breakfast            80     1401.5
# 10  Training Store    2022-01-03  10:00  Breakfast            87      650.0
# 11  Training Store    2022-01-03  11:00      Lunch            94      733.5
# 12  Training Store    2022-01-03  12:00      Lunch           101      817.0
# 13  Training Store    2022-01-03  13:00      Lunch           108      900.5
# 14  Training Store    2022-01-03  14:00      Lunch           115      984.0
# 15  Training Store    2022-01-03  15:00     Dinner           122     1067.5
# 16  Training Store    2022-01-03  16:00     Dinner           129     1151.0
# 17  Training Store    2022-01-03  17:00     Dinner           136     1234.5
# 18  Training Store    2022-01-03  18:00     Dinner            80     1318.0
# 19  Training Store    2022-01-03  19:00     Dinner            87     1401.5
# 20  Training Store    2022-01-03  20:00     Dinner            94      650.0
# 21  Training Store    2022-01-03  21:00     Dinner           101      733.5
# 22  Training Store    2022-01-03  22:00     Dinner           108      817.0
# 23  Training Store    2022-01-03  23:00     Dinner           115      900.5
# 24  Training Store    2022-01-04  00:00  Breakfast           122      984.0
# 25  Training Store    2022-01-04  01:00  Breakfast           129     1067.5
# 26  Training Store    2022-01-04  02:00  Breakfast           136     1151.0
# 27  Training Store    2022-01-04  03:00  Breakfast            80     1234.5
# 28  Training Store    2022-01-04  04:00  Breakfast            87     1318.0
# 29  Training Store    2022-01-04  05:00  Breakfast            94     1401.5
# 30  Training Store    2022-01-04  06:00  Breakfast           101      650.0
# 31  Training Store    2022-01-04  07:00  Breakfast           108      733.5
# 32  Training Store    2022-01-04  08:00  Breakfast           115      817.0
# 33  Training Store    2022-01-04  09:00  Breakfast           122      900.5
# 34  Training Store    2022-01-04  10:00  Breakfast           129      984.0
# 35  Training Store    2022-01-04  11:00      Lunch           136     1067.5
# 36  Training Store    2022-01-04  12:00      Lunch            80     1151.0
# 37  Training Store    2022-01-04  13:00      Lunch            87     1234.5
# 38  Training Store    2022-01-04  14:00      Lunch            94     1318.0
# 39  Training Store    2022-01-04  15:00     Dinner           101     1401.5
# 40  Training Store    2022-01-04  16:00     Dinner           108      650.0
# 41  Training Store    2022-01-04  17:00     Dinner           115      733.5
#
#     Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0         10.00                     120           4  Sample Manager    Rain
# 1         11.25                     129           5  Sample Manager   Clear
# 2         12.50                     138           6  Sample Manager   Clear
# 3         13.75                     147           7  Sample Manager   Clear
# 4         15.00                     156           8  Sample Manager    Rain
# 5         16.25                     165           4  Sample Manager   Clear
# 6         10.00                     174           5  Sample Manager   Clear
# 7         11.25                     183           6  Sample Manager   Clear
# 8         12.50                     120           7  Sample Manager    Rain
# 9         13.75                     129           8  Sample Manager   Clear
# 10        15.00                     138           4  Sample Manager   Clear
# 11        16.25                     147           5  Sample Manager   Clear
# 12        10.00                     156           6  Sample Manager    Rain
# 13        11.25                     165           7  Sample Manager   Clear
# 14        12.50                     174           8  Sample Manager   Clear
# 15        13.75                     183           4  Sample Manager   Clear
# 16        15.00                     120           5  Sample Manager    Rain
# 17        16.25                     129           6  Sample Manager   Clear
# 18        10.00                     138           7  Sample Manager   Clear
# 19        11.25                     147           8  Sample Manager   Clear
# 20        12.50                     156           4  Sample Manager    Rain
# 21        13.75                     165           5  Sample Manager   Clear
# 22        15.00                     174           6  Sample Manager   Clear
# 23        16.25                     183           7  Sample Manager   Clear
# 24        10.00                     120           8  Sample Manager    Rain
# 25        11.25                     129           4  Sample Manager   Clear
# 26        12.50                     138           5  Sample Manager   Clear
# 27        13.75                     147           6  Sample Manager   Clear
# 28        15.00                     156           7  Sample Manager    Rain
# 29        16.25                     165           8  Sample Manager   Clear
# 30        10.00                     174           4  Sample Manager   Clear
# 31        11.25                     183           5  Sample Manager   Clear
# 32        12.50                     120           6  Sample Manager    Rain
# 33        13.75                     129           7  Sample Manager   Clear
# 34        15.00                     138           8  Sample Manager   Clear
# 35        16.25                     147           4  Sample Manager   Clear
# 36        10.00                     156           5  Sample Manager    Rain
# 37        11.25                     165           6  Sample Manager   Clear
# 38        12.50                     174           7  Sample Manager   Clear
# 39        13.75                     183           8  Sample Manager   Clear
# 40        15.00                     120           4  Sample Manager    Rain
# 41        16.25                     129           5  Sample Manager   Clear
#
#     Promotion_Flag  Customer_Satisfaction            Timestamp
# 0             True                   4.00  2022-01-03 00:00:00
# 1            False                   4.15  2022-01-03 01:00:00
# 2            False                   4.30  2022-01-03 02:00:00
# 3            False                   4.45  2022-01-03 03:00:00
# 4            False                   4.60  2022-01-03 04:00:00
# 5            False                   4.00  2022-01-03 05:00:00
# 6            False                   4.15  2022-01-03 06:00:00
# 7             True                   4.30  2022-01-03 07:00:00
# 8            False                   4.45  2022-01-03 08:00:00
# 9            False                   4.60  2022-01-03 09:00:00
# 10           False                   4.00  2022-01-03 10:00:00
# 11           False                   4.15  2022-01-03 11:00:00
# 12           False                   4.30  2022-01-03 12:00:00
# 13           False                   4.45  2022-01-03 13:00:00
# 14            True                   4.60  2022-01-03 14:00:00
# 15           False                   4.00  2022-01-03 15:00:00
# 16           False                   4.15  2022-01-03 16:00:00
# 17           False                   4.30  2022-01-03 17:00:00
# 18           False                   4.45  2022-01-03 18:00:00
# 19           False                   4.60  2022-01-03 19:00:00
# 20           False                   4.00  2022-01-03 20:00:00
# 21            True                   4.15  2022-01-03 21:00:00
# 22           False                   4.30  2022-01-03 22:00:00
# 23           False                   4.45  2022-01-03 23:00:00
# 24           False                   4.60  2022-01-04 00:00:00
# 25           False                   4.00  2022-01-04 01:00:00
# 26           False                   4.15  2022-01-04 02:00:00
# 27           False                   4.30  2022-01-04 03:00:00
# 28            True                   4.45  2022-01-04 04:00:00
# 29           False                   4.60  2022-01-04 05:00:00
# 30           False                   4.00  2022-01-04 06:00:00
# 31           False                   4.15  2022-01-04 07:00:00
# 32           False                   4.30  2022-01-04 08:00:00
# 33           False                   4.45  2022-01-04 09:00:00
# 34           False                   4.60  2022-01-04 10:00:00
# 35            True                   4.00  2022-01-04 11:00:00
# 36           False                   4.15  2022-01-04 12:00:00
# 37           False                   4.30  2022-01-04 13:00:00
# 38           False                   4.45  2022-01-04 14:00:00
# 39           False                   4.60  2022-01-04 15:00:00
# 40           False                   4.00  2022-01-04 16:00:00
# 41           False                   4.15  2022-01-04 17:00:00

# %%
laborSheetData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Store                   42 non-null     object
#  1   Business_Date           42 non-null     object
#  2   Hour                    42 non-null     object
#  3   Day_Part                42 non-null     object
#  4   Transactions            42 non-null     int64
#  5   Net_Sales               42 non-null     float64
#  6   Labor_Hours             42 non-null     float64
#  7   Drive_Thru_Avg_Seconds  42 non-null     int64
#  8   Crew_Count              42 non-null     int64
#  9   Manager                 42 non-null     object
#  10  Weather                 42 non-null     object
#  11  Promotion_Flag          42 non-null     bool
#  12  Customer_Satisfaction   42 non-null     float64
#  13  Timestamp               42 non-null     object
# dtypes: bool(1), float64(3), int64(3), object(7)
# memory usage: 4.4+ KB

# %% [markdown]
# <a name=dtattribute></a>
# # Using .dt to access and operate on the datetime objects in a column
# I am sure you are wondering why we went to the trouble to convert the columns to the datetime data type. Well it let's us manipulate the datetimes much more easily. Let's see some basics below:
#
# First I read the data back in, correctly use the parse_dates argument.

# %%
laborSheetData = pd.read_csv(filepath)
# Convert 'Business_Date' to datetime
laborSheetData['Business_Date'] = pd.to_datetime(laborSheetData['Business_Date'])
# Combine 'Business_Date' and 'Hour' to create 'Date_Hour' column
laborSheetData['Date_Hour'] = pd.to_datetime(laborSheetData['Business_Date'].dt.date.astype(str) + ' ' + laborSheetData['Hour'].astype(str))
# Convert 'Timestamp' to datetime
laborSheetData['Timestamp'] = pd.to_datetime(laborSheetData['Timestamp'])
laborSheetData.head(2)
# Out:
#             Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0  Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1  Training Store    2022-01-03  01:00  Breakfast            87      733.5
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
#
#    Promotion_Flag  Customer_Satisfaction           Timestamp  \
# 0            True                   4.00 2022-01-03 00:00:00
# 1           False                   4.15 2022-01-03 01:00:00
#
#             Date_Hour
# 0 2022-01-03 00:00:00
# 1 2022-01-03 01:00:00

# %% [markdown]
# #### Use .dt to access the datetime properties, and then use .month to get the month of each value in the column

# %%
laborSheetData['Date_Hour'].dt.month.head(2)
# Out:
# 0    1
# 1    1
# Name: Date_Hour, dtype: int32

# %% [markdown]
# #### Use .dt and .year to get the year of each columns

# %%
laborSheetData['Date_Hour'].dt.year.head(2)
# Out:
# 0    2022
# 1    2022
# Name: Date_Hour, dtype: int32

# %% [markdown]
# #### Use .dt and .day to get the day of each columns

# %%
laborSheetData['Date_Hour'].dt.day.head(2)
# Out:
# 0    3
# 1    3
# Name: Date_Hour, dtype: int32

# %% [markdown]
# #### Use .dt and .hour to get the hour of each columns

# %%
laborSheetData['Date_Hour'].dt.hour.head(2)
# Out:
# 0    0
# 1    1
# Name: Date_Hour, dtype: int32

# %% [markdown]
# #### Use .dt and .hour and .value_counts() to get the row counts for each hour; do some hours get recorded less than others?

# %%
laborSheetData['Date_Hour'].dt.hour.value_counts()
# Out:
# Date_Hour
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 23    1
# Name: count, dtype: int64

# %% [markdown]
# #### Introducing .sort_index().  The .sort_index() method will sort the index of a dataframe (while reordering the rows appropriately)
#
# Note that the index of the value_counts() results is made up of the values that you are counting.

# %%
laborSheetData['Date_Hour'].dt.hour.value_counts().sort_index()
# Out:
# Date_Hour
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 23    1
# Name: count, dtype: int64

# %% [markdown]
# <a name=minmaxsum></a>
# ## Introducing the .min(), .max(), and .sum() methods.
# You can use these methods on any column, or dataframe to get the min, max, and sum of all numerical columns. You can also use the .min() and .max() methods to get the min and max of datetime columns

# %% [markdown]
# #### Use .min() and .max() to find the earliest and latest year in the data.

# %%
print(laborSheetData['Date_Hour'].min())
print(laborSheetData['Date_Hour'].max())
# Out:
# 2022-01-03 00:00:00
# 2022-01-04 17:00:00

# %% [markdown]
# #### Combine the use of .loc, .dt, and .sum() to find the total sales In August across all stores.

# %%
laborSheetData.loc[laborSheetData['Date_Hour'].dt.month == 8, 'Net_Sales'].sum()
# Out:
# np.float64(0.0)

# %% [markdown]
# #### Selecting rows greater than (or less than) a date.
# Getting rows greater than, or less than (or some combination of logic tests) is fairly easy.  You use your normal logic tests: >, <, ==, etc...  and pass the value you'd like to test against as a string.  See the example below, note how we are able to use the string '2017-08-01' to get all rows with a value in the 'TimeStamp' column greater than '2017-08-01'. Easy!

# %%
laborSheetData.loc[laborSheetData['TimeStamp'] > '2017-08-01', :].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TimeStamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_877/301235922.py in <cell line: 0>()
# ----> 1 laborSheetData.loc[laborSheetData['TimeStamp'] > '2017-08-01', :].head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'TimeStamp'

# %%
print(laborSheetData['Timestamp'].min())
print(laborSheetData['Timestamp'].max())
# Out:
# 2022-01-03 00:00:00
# 2022-01-04 17:00:00

# %% [markdown]
# # Changing the time zone of a datetime column
# Pandas includes some easy functionality to convert the timezone of a datetime column.  The first thing we need to do is 'localize' the column - this means defining what timezone the original data is in.  They data we have been using happens to be from fast food location on the west coast, so we will localize the timestamp column to the 'US/Pacific' timezone by using the tz_localize() method.

# %%
laborSheetData['Timestamp'] = laborSheetData['Timestamp'].dt.tz_localize('US/Pacific')
laborSheetData.head()
# Out:
#             Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0  Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1  Training Store    2022-01-03  01:00  Breakfast            87      733.5
# 2  Training Store    2022-01-03  02:00  Breakfast            94      817.0
# 3  Training Store    2022-01-03  03:00  Breakfast           101      900.5
# 4  Training Store    2022-01-03  04:00  Breakfast           108      984.0
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
# 2        12.50                     138           6  Sample Manager   Clear
# 3        13.75                     147           7  Sample Manager   Clear
# 4        15.00                     156           8  Sample Manager    Rain
#
#    Promotion_Flag  Customer_Satisfaction                 Timestamp  \
# 0            True                   4.00 2022-01-03 00:00:00-08:00
# 1           False                   4.15 2022-01-03 01:00:00-08:00
# 2           False                   4.30 2022-01-03 02:00:00-08:00
# 3           False                   4.45 2022-01-03 03:00:00-08:00
# 4           False                   4.60 2022-01-03 04:00:00-08:00
#
#             Date_Hour
# 0 2022-01-03 00:00:00
# 1 2022-01-03 01:00:00
# 2 2022-01-03 02:00:00
# 3 2022-01-03 03:00:00
# 4 2022-01-03 04:00:00

# %%
laborSheetData.loc[:, 'TimeStamp'] = laborSheetData['TimeStamp'].dt.tz_localize('US/Pacific')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TimeStamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_877/2063929610.py in <cell line: 0>()
# ----> 1 laborSheetData.loc[:, 'TimeStamp'] = laborSheetData['TimeStamp'].dt.tz_localize('US/Pacific')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'TimeStamp'

# %%
laborSheetData.isnull().sum()
# Out:
# Store                     0
# Business_Date             0
# Hour                      0
# Day_Part                  0
# Transactions              0
# Net_Sales                 0
# Labor_Hours               0
# Drive_Thru_Avg_Seconds    0
# Crew_Count                0
# Manager                   0
# Weather                   0
# Promotion_Flag            0
# Customer_Satisfaction     0
# Timestamp                 0
# Date_Hour                 0
# Timestamp_UTC             0
# dtype: int64

# %%
laborSheetData.head()
# Out:
#             Store Business_Date   Hour   Day_Part  Transactions  Net_Sales  \
# 0  Training Store    2022-01-03  00:00  Breakfast            80      650.0
# 1  Training Store    2022-01-03  01:00  Breakfast            87      733.5
# 2  Training Store    2022-01-03  02:00  Breakfast            94      817.0
# 3  Training Store    2022-01-03  03:00  Breakfast           101      900.5
# 4  Training Store    2022-01-03  04:00  Breakfast           108      984.0
#
#    Labor_Hours  Drive_Thru_Avg_Seconds  Crew_Count         Manager Weather  \
# 0        10.00                     120           4  Sample Manager    Rain
# 1        11.25                     129           5  Sample Manager   Clear
# 2        12.50                     138           6  Sample Manager   Clear
# 3        13.75                     147           7  Sample Manager   Clear
# 4        15.00                     156           8  Sample Manager    Rain
#
#    Promotion_Flag  Customer_Satisfaction                 Timestamp  \
# 0            True                   4.00 2022-01-03 00:00:00-08:00
# 1           False                   4.15 2022-01-03 01:00:00-08:00
# 2           False                   4.30 2022-01-03 02:00:00-08:00
# 3           False                   4.45 2022-01-03 03:00:00-08:00
# 4           False                   4.60 2022-01-03 04:00:00-08:00
#
#             Date_Hour             Timestamp_UTC
# 0 2022-01-03 00:00:00 2022-01-03 08:00:00+00:00
# 1 2022-01-03 01:00:00 2022-01-03 09:00:00+00:00
# 2 2022-01-03 02:00:00 2022-01-03 10:00:00+00:00
# 3 2022-01-03 03:00:00 2022-01-03 11:00:00+00:00
# 4 2022-01-03 04:00:00 2022-01-03 12:00:00+00:00

# %%
laborSheetData.loc[:, 'Timestamp_UTC'] = laborSheetData['Timestamp'].dt.tz_convert('UTC')

# %%
laborSheetData[['Timestamp', 'Timestamp_UTC']].head()
# Out:
#                   Timestamp             Timestamp_UTC
# 0 2022-01-03 00:00:00-08:00 2022-01-03 08:00:00+00:00
# 1 2022-01-03 01:00:00-08:00 2022-01-03 09:00:00+00:00
# 2 2022-01-03 02:00:00-08:00 2022-01-03 10:00:00+00:00
# 3 2022-01-03 03:00:00-08:00 2022-01-03 11:00:00+00:00
# 4 2022-01-03 04:00:00-08:00 2022-01-03 12:00:00+00:00

# %% [markdown]
# # Using .date_range() to create a DateTime index
#
# We can easily create a DateTime index by using the .date_range() method. We just need to pass a start date, and end date (or a number of periods) and a frequency (the amount of time between each value in the series of values).  Possible values for freq are:
# * s (for seconds)
# * min (for minutes)
# * H (for hours)
# * D (for days)
# * A (for annual, ending on the end of a year)
# * AS (for annual, ending on the start of a year)
# * You can also do multiples, i.e. 3H for a step of 3 hours.
# * You can also use something called a DateOffset object for more custom steps, but that is beyond the scope of this course.
#
# Note that, once you create an index, you can use it as a row index or column in a dataframe.
#
# The docs for this method are here: <https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html>
#
# Let's look at some examples:

# %% [markdown]
# #### Create a DatetimeIndex with a start date of 2001-01-01, an end date of 2002-01-01 and a step of 3 hours.

# %%
pd.date_range(start='2001-01-01', end='2002-01-01', freq='3H')
# Out:
# /tmp/ipykernel_877/2840347437.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2001-01-01', end='2002-01-01', freq='3H')
# DatetimeIndex(['2001-01-01 00:00:00', '2001-01-01 03:00:00',
#                '2001-01-01 06:00:00', '2001-01-01 09:00:00',
#                '2001-01-01 12:00:00', '2001-01-01 15:00:00',
#                '2001-01-01 18:00:00', '2001-01-01 21:00:00',
#                '2001-01-02 00:00:00', '2001-01-02 03:00:00',
#                ...
#                '2001-12-30 21:00:00', '2001-12-31 00:00:00',
#                '2001-12-31 03:00:00', '2001-12-31 06:00:00',
#                '2001-12-31 09:00:00', '2001-12-31 12:00:00',
#                '2001-12-31 15:00:00', '2001-12-31 18:00:00',
#                '2001-12-31 21:00:00', '2002-01-01 00:00:00'],
#               dtype='datetime64[ns]', length=2921, freq='3h')

# %% [markdown]
# #### Create a DatetimeIndex with a start date of 2001-01-01 and a  frequency of 1 day that continues for 100 periods.

# %%
pd.date_range(start='2001-01-01', periods=100, freq='D')
# Out:
# DatetimeIndex(['2001-01-01', '2001-01-02', '2001-01-03', '2001-01-04',
#                '2001-01-05', '2001-01-06', '2001-01-07', '2001-01-08',
#                '2001-01-09', '2001-01-10', '2001-01-11', '2001-01-12',
#                '2001-01-13', '2001-01-14', '2001-01-15', '2001-01-16',
#                '2001-01-17', '2001-01-18', '2001-01-19', '2001-01-20',
#                '2001-01-21', '2001-01-22', '2001-01-23', '2001-01-24',
#                '2001-01-25', '2001-01-26', '2001-01-27', '2001-01-28',
#                '2001-01-29', '2001-01-30', '2001-01-31', '2001-02-01',
#                '2001-02-02', '2001-02-03', '2001-02-04', '2001-02-05',
#                '2001-02-06', '2001-02-07', '2001-02-08', '2001-02-09',
#                '2001-02-10', '2001-02-11', '2001-02-12', '2001-02-13',
#                '2001-02-14', '2001-02-15', '2001-02-16', '2001-02-17',
#                '2001-02-18', '2001-02-19', '2001-02-20', '2001-02-21',
#                '2001-02-22', '2001-02-23', '2001-02-24', '2001-02-25',
#                '2001-02-26', '2001-02-27', '2001-02-28', '2001-03-01',
#                '2001-03-02', '2001-03-03', '2001-03-04', '2001-03-05',
#                '2001-03-06', '2001-03-07', '2001-03-08', '2001-03-09',
#                '2001-03-10', '2001-03-11', '2001-03-12', '2001-03-13',
#                '2001-03-14', '2001-03-15', '2001-03-16', '2001-03-17',
#                '2001-03-18', '2001-03-19', '2001-03-20', '2001-03-21',
#                '2001-03-22', '2001-03-23', '2001-03-24', '2001-03-25',
#                '2001-03-26', '2001-03-27', '2001-03-28', '2001-03-29',
#                '2001-03-30', '2001-03-31', '2001-04-01', '2001-04-02',
#                '2001-04-03', '2001-04-04', '2001-04-05', '2001-04-06',
#                '2001-04-07', '2001-04-08', '2001-04-09', '2001-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# #### Create a DatetimeIndex with a start date of 1970-01-01, that continues for 10 periods, and has an annual frequency - on the first day of each year.

# %%
pd.date_range(start='1970-01-01', periods=10, freq='AS')
# Out:
# /tmp/ipykernel_877/3156283219.py:1: FutureWarning: 'AS' is deprecated and will be removed in a future version, please use 'YS' instead.
#   pd.date_range(start='1970-01-01', periods=10, freq='AS')
# DatetimeIndex(['1970-01-01', '1971-01-01', '1972-01-01', '1973-01-01',
#                '1974-01-01', '1975-01-01', '1976-01-01', '1977-01-01',
#                '1978-01-01', '1979-01-01'],
#               dtype='datetime64[ns]', freq='YS-JAN')

# %% [markdown]
# #### Create a DatetimeIndex with a start date of 1970-01-01, that continues for 10 periods, and has an annual frequency - on the last day of each year.

# %%
pd.date_range(start='1969-12-31', periods=10, freq='A')
# Out:
# /tmp/ipykernel_877/2341819708.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   pd.date_range(start='1969-12-31', periods=10, freq='A')
# DatetimeIndex(['1969-12-31', '1970-12-31', '1971-12-31', '1972-12-31',
#                '1973-12-31', '1974-12-31', '1975-12-31', '1976-12-31',
#                '1977-12-31', '1978-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %% [markdown]
# #### Create a DatetimeIndex with a start date of 2001-01-01 and a step size of 1 day that continues for 100 steps.

# %%
pd.date_range(start='1969-12-31', periods=10, freq='A-AUG')
# Out:
# /tmp/ipykernel_877/2874970740.py:1: FutureWarning: 'A-AUG' is deprecated and will be removed in a future version, please use 'YE-AUG' instead.
#   pd.date_range(start='1969-12-31', periods=10, freq='A-AUG')
# DatetimeIndex(['1970-08-31', '1971-08-31', '1972-08-31', '1973-08-31',
#                '1974-08-31', '1975-08-31', '1976-08-31', '1977-08-31',
#                '1978-08-31', '1979-08-31'],
#               dtype='datetime64[ns]', freq='YE-AUG')
