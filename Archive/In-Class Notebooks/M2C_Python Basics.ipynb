# %% [markdown]
# ## M2_Booleans

# %%
# One more interesting example:
myTuple = (-1.1, 3.4, 0)

if myTuple[2] == 0 and myTuple[0] < 0:
    print(myTuple[1])
# Out:
# 3.4

# %%
myBool= False
myOtherBool = True
print(myBool)
print(myOtherBool)
# Out:
# False
# True

# %% [markdown]
# ## M2_Length

# %%
len('car')

# %%
len([1,3,4,5])

# %%
shape.()

# %% [markdown]
# # M2_Lists

# %% [markdown]
# ## Lists
# List can be useful whenever you want to collect other variable in a list. For example,
# let's say we are reading in a data file of user email addresses and demographic data
# and we want to collect the email address of users that meet a certain criteria - you
# could collect the emails in a list.
#
# Below you will see some examples of using lists:

# %%
# This is a list of numbers:
list1 = [3, 2, 3]

# This is a list of numbers and strings
list2 = [4.3, 1.2, 'Austin']

# We can access items in the lists through an index - note that python uses
# 0 indexing - which means the first element is at index 0. Note we use square
# brackets when indexing a list.

print('list1:', list1[0])

print('list2:', list2[2])

# We can also update items in the list by using indexing
list1[0] = 'hello'
print('updated list1:', list1)

# Please make some lists below, and the print items from them
# Out:
# list1: 3
# list2: Austin
# updated list1: ['hello', 2, 3]

# %%
string1 = 'will'
string2 = string1
print(string2)
string2 = 'jane'
print(string2)
print(string1)
# Out:
# will
# jane
# will

# %%
# Be careful about pointing multiple variable names at the same list. Notice
# how below we change list2 and also changes list1. This is because both
# variable names are pointing to the same list object in memory.

list1 = [3, 2, 3]
list2 = list1
list2[0] = -7
print('list1:', list1)

# you can always copy  a list using the copy() method

list1 = [3, 2, 3]
list2 = list1.copy()
list2[0] = -7
print('list1:', list1)

dog = [1, 2]
print(type(dog))
print(dog)
# Out:
# list1: [-7, 2, 3]
# list1: [3, 2, 3]
# <class 'list'>
# [1, 2]

# %% [markdown]
# ## Growing and Concatenating Lists
# We can add items to list, and combine lists. Let's look at some examples below:

# %%
# Adding items to lists is a simple as using the append method:
myString = 'apple'
list1 = ['a', 'b', 'c']
list1.append(myString)
print('list1:', list1)

# Please create a list below and append items to it.
# Out:
# list1: ['a', 'b', 'c', 'apple']

# %%
# We combine two lists with the '+' operator
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list1 = list1 + list2
print('list3:', list1)
# Out:
# list3: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Deleting Items From List

# %%
myString = 'apple'
list1 = ['a', myString, 'd']
del list1[0]
print(list1)
# Out:
# ['apple', 'd']

# %%
# please create some lists below and concatenate them together, then append items, and delete items.

# %% [markdown]
# # M2_For Loops
# For loops are used to repeat a block of code a certain number of times. Let's see some examples below.

# %%
myBool= False
myOtherBool = True
print(myBool)
print(myOtherBool)
# Out:
# False
# True

# %%
# for loops will iterate through values in a list. (In fact, you can use any
# iterator object, but a list is the most common)
myList = [0, 1, 2, 3, 4]
for number in myList:
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # M2 - Tuples

# %% [markdown]
# ## Tuples
# Tuple are like lists except they are immutable meaning you can not change them once you have created them. Creating a tuple is like creating a list, except we use round bracket () instead of square brackets []. One advantage tuples have is 'packing' and 'unpacking'. We will see some examples of this below.

# %%
# First let's make a tuple!
myTuple = (5, 'Apples')
print(myTuple)
# Out:
# (5, 'Apples')

# %%
# Now, let's try and update it - remember this will return an error, because we can't do this.
myTuple[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4873/2983901041.py in <cell line: 0>()
#       1 # Now, let's try and update it - remember this will return an error, because we can't do this.
# ----> 2 myTuple[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Tuple Unpacking
#
# Tuple unpacking is a convenient way to assign elements of a tuple to multiple variables at once. The number of variables on the left-hand side of the assignment must match the number of elements in the tuple. This is particularly useful when a function returns a tuple, or when you want to swap variable values easily.

# %%
# Example of tuple unpacking
coordinates = (10, 20)
x, y = coordinates
print(f"x: {x}, y: {y}")

# Another example: swapping values
a = 5
b = 10
print(f"Before swap: a={a}, b={b}")
a, b = b, a # Unpacking with a temporary tuple (b, a)
print(f"After swap: a={a}, b={b}")

# Unpacking from a function's return value
def get_user_info():
    return ("Alice", 30, "New York")

name, age, city = get_user_info()
print(f"User Info: Name={name}, Age={age}, City={city}")
# Out:
# x: 10, y: 20
# Before swap: a=5, b=10
# After swap: a=10, b=5
# User Info: Name=Alice, Age=30, City=New York

# %%
myTuple[0]
# Out:
# 5

# %% [markdown]
# # M2 - Dictionaries

# %% [markdown]
# ## Dictionary
# Dictionaries allow us to store data in key value pairs.  This means that we can label the data elements in the dictionary. For example, we could create a dictionary that contains user informations, like name, age, and state.

# %%
# We can define a dictionary like seen below.  Note the use of curly brackets,
# {}, and the ':' used to separate the key and value.

# This dictionary has 3 pieces of data, the keys are 'name', 'age' and 'state.
# The values are show below.
newDict = {'name': 'Jill Smith', 'age': 35, 'state': 'OR'}

# We can access the data using the keys
userName = newDict['name']
print(userName)

print(newDict)

# We can remove items from the dictionary using 'del', just like we did with lists
del newDict['age']
print(newDict)

# We can add items to a dictionary in the following way:
newDict['height'] = 5.1
print(newDict)

nameList =['will', 'jill']
newDict['name'] = nameList[1]
print(newDict)

tempDict = {}
tempDict[(11.0, 45.0)] = 75.4
print(tempDict)
# Out:
# Jill Smith
# {'name': 'Jill Smith', 'age': 35, 'state': 'OR'}
# {'name': 'Jill Smith', 'state': 'OR'}
# {'name': 'Jill Smith', 'state': 'OR', 'height': 5.1}
# {'name': 'jill', 'state': 'OR', 'height': 5.1}
# {(11.0, 45.0): 75.4}

# %%
# Also, note that keys can be strings, tuples, or numbers
myDict = {}
myDict[(1, 2)] = 'apple'
print(myDict)
# Out:
# {(1, 2): 'apple'}

# %%
# In the space below, please create a dictionary, access some of the values
# using the keys. Add new values using the method shown above, and delete some
# values as well.
nestedDict = {}
nestedDict['person1'] = {}
nestedDict['person1']['name'] = 'will'
nestedDict['person2'] = {'name': 'jill'}

print(nestedDict)
# Out:
# {'person1': {'name': 'will'}, 'person2': {'name': 'jill'}}

# %%
# Speaking of iterator objects, we can create one using range.  Range(n) will
# generate numbers from 0 to n-1.  For example, range(5) returns a range object
# which we can use to iterate from 0 to 4.
# The idea of an iterator may be confusing, but just think if it as a list,
# except only one value in the list is in memeory at a time.  So instead of
# creating the list [0, 1, 2, 3, 4], you have created a range object that
# "counts" from 0 to 4, one number at a time.
range(5) # will generate numbers from 0 to 4
# Out:
# range(0, 5)

# %%
# You can actually convert a range object to a list using the list() function.
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
# Often, range() is used in for loops. This loop will iterate from 0 to 4.
# That isthe variable number will take on the values 0, 1, 2, 3, 4.
for number in range(8):
    print(number // 2)
# Out:
# 0
# 0
# 1
# 1
# 2
# 2
# 3
# 3

# %%
# But what if you want to loop over something other than numbers? We can do
# that just as easily.

listOfFiles = ['file1', 'file2', 'file3']
for x in listOfFiles:
    print(x)
# Out:
# file1
# file2
# file3

# %%
# This loop loops over strings, names, and tuples in a list. This example
# just shows how a for loop will iterate over a list that contains all kinds
# of variables.
myList = [1, 'Austin', 7.6, (4,5), ['W', 'H', 'L']]
for val in myList:
    print(val)
# Out:
# 1
# Austin
# 7.6
# (4, 5)
# ['W', 'H', 'L']

# %%
# We can put if/else statements inside a for loop (we can put any code we
# want inside a for loop)
for n in range(1000):
    if n % 7 == 0:
        print(n, ' is divisible by 7')
# Out:
# 0  is divisible by 7
# 7  is divisible by 7
# 14  is divisible by 7
# 21  is divisible by 7
# 28  is divisible by 7
# 35  is divisible by 7
# 42  is divisible by 7
# 49  is divisible by 7
# 56  is divisible by 7
# 63  is divisible by 7
# 70  is divisible by 7
# 77  is divisible by 7
# 84  is divisible by 7
# 91  is divisible by 7
# 98  is divisible by 7
# 105  is divisible by 7
# 112  is divisible by 7
# 119  is divisible by 7
# 126  is divisible by 7
# 133  is divisible by 7
# 140  is divisible by 7
# 147  is divisible by 7
# 154  is divisible by 7
# 161  is divisible by 7
# 168  is divisible by 7
# 175  is divisible by 7
# 182  is divisible by 7
# 189  is divisible by 7
# 196  is divisible by 7
# 203  is divisible by 7
# 210  is divisible by 7
# 217  is divisible by 7
# 224  is divisible by 7
# 231  is divisible by 7
# 238  is divisible by 7
# 245  is divisible by 7
# 252  is divisible by 7
# 259  is divisible by 7
# 266  is divisible by 7
# 273  is divisible by 7
# ...

# %%
# Can also 'skip' a loop in the for loop, but still continue the loop, using
# the 'continue' keyword.
for val in range(3):
    if val == 1:
        continue
    newVal = val**2
    print(newVal)
# Out:
# 0
# 4

# %%
# You can also exit a loop using the break keyword:
for word in ['apple', 'oregon', 'washington']:
    print(word)
    if word == 'oregon':
        break
# Out:
# apple
# oregon

# %%
# In this cell, please create a couple for loops and include an if/else block
# inside the loop.

# %% [markdown]
# # M2_If/Else
# If/Else blocks are our first look at a topic called 'flow' control! Flow control refers to methods that allow our script/program to do one thing or another depending on the current state of the program. Note the colons at the end of each 'if', 'else', and 'elif' line and the indentation each if/elif/else statement - this is mandatory!

# %%
# First Example:
myWord = 'basil'

if len(myWord) <= 3:
    print('short word')
else:
    print('long word')
# Out:
# long word

# %%
# For example, consider a script that determines shipping cost based on the
# weight of a package:
packageWeight = 8

if packageWeight < 10:
    cost = 5
elif packageWeight >= 10 and packageWeight < 15:
    cost = 7
else: # package must have a weight >= 15 if the above if/else blocks havennot been triggered.
    cost = 15

print('The shipping cost is ', cost)
# Out:
# The shipping cost is  5

# %%
# Note that we can have as many 'elif' portions of an if/else statment as needed:
packageWeight = 40
if packageWeight < 10:
    cost = 5
elif packageWeight >= 10 and packageWeight < 15:
    cost = 7
elif packageWeight >= 15 and packageWeight < 20:
    cost = 10
elif packageWeight >= 20 and packageWeight < 35:
    cost = 12
else: # package must have a weight >= 35 if the above if/else blocks haven not been triggered.
    cost = 18

print('The shipping cost is ', cost)
# Out:
# The shipping cost is  18

# %%
# In the space below please create an if else block that will print the
# following statements based on the values of the variable a and b (shown below)

# if a and b are both positive, print 'both a and b are positive'
# if a and b are both negative, print 'both a and b are negative'
# if a and b are not both negative or positive, then print 'a and b are not
# both positive or both negative'

# remember you can capture one of the conditions above in the 'else' block.

# once you have created this if/else block, test it by changing the values of a, b

a = 2
b = -7

# %%
# Often, an if else block will be built around if a list is empty. For example,
# you could scan a directory for data files and store the file paths in a list.
# You then need to check if the list is empty or not - it might be empty if no
# files were found in the directory. We see that example below, not that the boolean
# value of an empty list is False, while the boolean value of a non-empty list
# is True.

listOfFiles = ['a.txt']

if listOfFiles:
    print('files found')
else: # the list is empty
    print('no files found')
# Out:
# files found

# %% [markdown]
# ---
#
# # Additional Students' Practice and Answer Key
#
# These practice questions are designed for undergraduate students. Try the **Student Practice** cell first, then compare your work with the **Completed Answer** cell.

# %% [markdown]
# ## Student Practice 1: Variables and Lists
# Create variables for a student's name and three grades. Store the grades in a list and print the student's average.
#
# ## Student Practice 2: Loop Practice
# Loop through the grades and print each grade.

# %%
# Completed Answer 1: Variables and Lists
student_name = 'Alex'
grades = [88, 91, 84]
average_grade = sum(grades) / len(grades)
print(student_name, 'average grade:', average_grade)

# Completed Answer 2: Loop Practice
for grade in grades:
    print('Grade:', grade)
